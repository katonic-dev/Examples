# %% [markdown]
# # Patient Diabetes Prediction
#
# This dataset is originally from the National Institute of Diabetes and Digestive and Kidney Diseases.
#
# The objective of the dataset is to diagnostically predict whether or not a patient has diabetes, based on certain diagnostic measurements included in the dataset. Several constraints were placed on the selection of these instances from a larger database. In particular, all patients here are females at least 21 years old of Pima Indian heritage.

# %% [markdown]
# ### Imports

# %%
import os
os.system("pip install katonic[ml]")

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from itertools import cycle

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from katonic.log.client import load_model

from katonic.ml.classification import Classifier

# %% [markdown]
# ## Data Prepration

# %%
exp_name = 'diabetes_prediction3'

# %%
# loading diabetes data from github
df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/diabetes.csv')

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# The datasets consists of several medical predictor variables and one target variable **Outcome**. Predictor variables includes the number of pregnancies the patient has had, their BMI, insulin level, age, and so on.

# %%
def resumetable(df):
    print(f"Dataset Shape: {df.shape}")
    summary = pd.DataFrame(df.dtypes,columns=['dtypes'])
    summary = summary.reset_index()
    summary['Name'] = summary['index']
    summary = summary[['Name','dtypes']]
    summary['Missing'] = df.isnull().sum().values    
    summary['Uniques'] = df.nunique().values
   
    return summary

# %%
resumetable(df)
# Out:
# Dataset Shape: (768, 9)
#                        Name   dtypes  Missing  Uniques
# 0               Pregnancies    int64        0       17
# 1                   Glucose    int64        0      136
# 2             BloodPressure    int64        0       47
# 3             SkinThickness    int64        0       51
# 4                   Insulin    int64        0      186
# 5                       BMI  float64        0      248
# 6  DiabetesPedigreeFunction  float64        0      517
# 7                       Age    int64        0       52
# 8                   Outcome    int64        0        2

# %% [markdown]
# **To fill these missing values the data distribution needs to be understood against the target.**

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# Let's check the skewness of each of the columns.

# %%
for col in df.drop('Outcome', axis = 1).columns:
    print(f"Skewness for the column {col} is {df[col].skew()}")
# Out:
# Skewness for the column Pregnancies is 0.9016739791518588
# Skewness for the column Glucose is 0.17375350179188992
# Skewness for the column BloodPressure is -1.8436079833551302
# Skewness for the column SkinThickness is 0.10937249648187608
# Skewness for the column Insulin is 2.272250858431574
# Skewness for the column BMI is -0.42898158845356543
# Skewness for the column DiabetesPedigreeFunction is 1.919911066307204
# Skewness for the column Age is 1.1295967011444805

# %%
fig, axes = plt.subplots(4, 2, figsize=(15, 10))
axes = axes.flatten()
columns = df.drop('Outcome', axis = 1).columns
color_cycle = cycle(plt.rcParams['axes.prop_cycle'].by_key()['color'])
for ax_idx, col in enumerate(columns):
    df[col].plot(kind = 'hist', ax = axes[ax_idx], title = col, color = next(color_cycle))
plt.suptitle('Trends')
plt.tight_layout()
plt.show()

# %% [markdown]
# - Columns like `Pregnancies`, `Glucose`, `BloodPressure`, `SkinThickness` and `BMI` are not that much skewed. **We can fill null values with the mean for these columns.**
# - Columns like `Insulin` and `DiabetesPedigreeFunction`,**We have to replace them with median due to the effect of skewness.**

# %% [markdown]
# #### Filling null values

# %%
# Filling null values with the median.
df['Insulin'] = df['Insulin'].fillna(df['Insulin'].median()) 

# Filling null values with the mean.
for col in ['Glucose', 'BloodPressure', 'SkinThickness', 'BMI']:
    df[col] = df[col].fillna(df[col].mean())

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# All null values are taken care of now

# %% [markdown]
# ##### We would know what is the effect of Age on the Outcome because we have heard that as the age increases, the chances of diabetes also commonly increases.

# %%
sns.boxplot(x = 'Outcome', y = 'Age', data = df)
plt.title('Age vs Outcome')
plt.show()

# %% [markdown]
# Yes, we were right, The median of the age of diabetic people is greater than that of non-diabetic people.

# %% [markdown]
# ##### The effect of Blood Pressure on the Outcome.

# %%
sns.boxplot(x = 'Outcome', y = 'BloodPressure', data = df, palette = 'Blues')
plt.title('BP vs Outcome')
plt.show()

# %% [markdown]
# The median of the BloodPressure of diabetic people lies close to the 75th Percentile of non-diabetic people.

# %% [markdown]
# ##### The relationship between age and BP

# %%
sns.scatterplot(x='Age',y='BloodPressure', data=df, color = 'green');

# %% [markdown]
# As the age increases, generally the Blood Pressure also increases

# %% [markdown]
# A **correlation matrix** is a table showing correlation coefficients between sets of variables.

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(df.corr(), annot=True);

# %% [markdown]
# - From the above heatmap, we can observe that all the features are weakly correlated, so that removes multicollinearity out of equation.
#
# Multicollinearity (also collinearity) is a phenomenon in which one predictor variable in a multiple regression model can be linearly predicted from the others with a substantial degree of accuracy. Models like Logistic Regression assumes the presence of non-collinearity among the features, if multicollinearity is present it can lead to the bad performance of such models

# %% [markdown]
# ## Dataset Splitting

# %%
x = df.drop(columns=['Outcome'], axis=1)
y = df['Outcome']

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=98)

# %% [markdown]
# ## Features Scaling

# %%
sc = StandardScaler()
X_train =  pd.DataFrame(sc.fit_transform(X_train),
        columns=['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin','BMI', 'DiabetesPedigreeFunction', 'Age'])
X_test = pd.DataFrame(sc.fit_transform(X_test),
        columns=['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin','BMI', 'DiabetesPedigreeFunction', 'Age'])

# %% [markdown]
# ## Classification Models

# %% [markdown]
# #### Create object of Classifier class

# %%
features = list(X_train.columns)
clf = Classifier(X_train,X_test,y_train,y_test, exp_name, source_name='diabetes-prediction.ipynb', features=features)

# %%
exp_id = clf.id
print("experiment name : ", clf.name)
print("experiment location : ", clf.location)
print("experiment id : ", clf.id)
print("experiment status : ", clf.stage)
# Out:
# experiment name :  diabetes_prediction3
# experiment location :  s3://models/2
# experiment id :  2
# experiment status :  active

# %% [markdown]
# #### Clear previous runs

# %%
run_list = clf.search_runs(exp_id)['run_id'].tolist()
if run_list:
    clf.delete_run_by_id(run_list)
# Out:
# f2c99cd7fafe4e0ca8ebac635a8f9dee, 38f6ca3b7060423fa5b463203e91bf7f, 5296a355ccaa45ac9a2524483fa61d83, af09f399ea18466ca26b4147c886ef0a, 5083c736a6ed47febdcc0000293d7976, 289e8cb9edb14311b7ea89894bd358d8, 82a75e71f96d4752a52c928b005df8f4, 27298e73ea264231a8128ca5f6356ccf, 6643664ea56b452a93f589ecd4a13bbf, 3869b3ab3cec48d186f761356f80a954, 854dc1a12fad4d3b854820c7efcd076b, ae87ee01efb1495398185a1f7779193b, 024fb292451b4a35990ef62590eeec13, dbf7012516444956bb9cca311058a414, b2bcfc414b834b5bab76527ec68e1548, 5e8a9b262b4d4327b8af237744c51a19, e09694b6292b470b924d0d3746e1ffd3, 00fb9e4131d44ccfb9870d52c2497906, 5ac00daa9f684d82b56bfd49740c3fe1, 066c5fd5f0094d9cb7a6d522fce99861, 54e67dcb1e4844cbbff1fc057bce84a7, 3993786cbe5a462cbe6f36f4468e6218, 097c7822d1484f2db6b97936f2b76483, 495092f08bf74b3fb2a86e590a84717a, 6834ec08db3b4363bc579eb2d7c74f0e, d991a0ba4b3e4d88998b4cba7ae266da, bf02c2cdb5484f4697871c79f2fe2dd1, ceb5ecb80e724d15bcc4434076c488a7, f2cdf13325f84d91a20946c7453b3db3, 4c1937a363c84133803c4a8425a78be5, 7dbd2c23c40c43b7a7c4ed8e5cee3ce6, 03d0f118c94c482fa716af7fb8968e4f, 255fc4e7bf2e40929be932952c801b9c, 514f82640b524ec39fc7530e41068e15, 06d6b60e90b74da5ad44b019ac264bad, eeb82cfefbc84c34aabf0efba299958b, 614796ee8c67475b991c8afd0b986a11, 1f1398340f7347f9b7bb78145a9115c0, 6b82fa28d1f645f28d9740741000360c, 9d27bcbe8de746a3947a2bf45807011c, 018cd65c8c9b4fb7b61f4e5474a886f3, 1e53320a1abe47d2b6b3e9b67c8468f9, 21c177bb6c57423ca507302b6f0c67ea, 7afaa265a8e74949b1aad4994226b62f, 5f43ed08e0d245c7968463858eaaf6dd, 17c98d550d9148c0871efb8fe657e4ac, 61aa43b7c32e41b9bdf902f36be31f3e, fcfee94338fd47e7b7fc2c807d12ef4f, 540fa25cc30041039bce657738631894, 10187f8f962c4b759a613d3872f7157c, 465498038cb44d358531d71cd8355595, ca6136703df4409891f8171788db175d, e75b27cb51764b4c9f7e0ef7ad4cf249 run-ids successfully deleted

# %% [markdown]
# ### Logistic Regression

# %% [markdown]
# #### Set up parameters for tuning

# %%
params={
'solver':{
    'values': ['liblinear', 'lbfgs', 'sag'],
    'type': 'categorical'
},
    'C':{
        'low': 0.6,
        'high': 1.0,
        'type': 'float'
    }
}

# %%
clf.LogisticRegression(True, params=params)
# Out:
# [I 2023-10-23 14:44:36,748] A new study created in memory with name: no-name-bbc7eeeb-d2f4-4c48-a198-cd2f64b01d60
# [I 2023-10-23 14:44:38,582] Trial 0 finished with value: 0.7523076923076923 and parameters: {'solver': 'lbfgs', 'C': 0.7}. Best is trial 0 with value: 0.7523076923076923.
# [I 2023-10-23 14:44:40,429] Trial 1 finished with value: 0.7523076923076923 and parameters: {'solver': 'liblinear', 'C': 0.7}. Best is trial 0 with value: 0.7523076923076923.
# [I 2023-10-23 14:44:42,271] Trial 2 finished with value: 0.7523076923076923 and parameters: {'solver': 'sag', 'C': 0.6}. Best is trial 0 with value: 0.7523076923076923.
# [I 2023-10-23 14:44:43,990] Trial 3 finished with value: 0.7523076923076923 and parameters: {'solver': 'sag', 'C': 0.6}. Best is trial 0 with value: 0.7523076923076923.
# [I 2023-10-23 14:44:45,772] Trial 4 finished with value: 0.7523076923076923 and parameters: {'solver': 'sag', 'C': 0.7}. Best is trial 0 with value: 0.7523076923076923.
# Number of finished trials:  5
# Best trial:
#   auc_roc_score:  0.7523076923076923
#   Params:
#     solver: lbfgs
#     C: 0.7
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_25.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ### Decision Tree

# %% [markdown]
# #### Set up parameters for tuning

# %%
params = {
'max_depth': {
    'low': 8,
    'high': 15,
    'type': 'int'
    },
'criterion':{
    'values': ['gini', 'entropy'],
    'type': 'categorical'
    },
'splitter':{
    'values': ['best', 'random'],
    'type': 'categorical'
    },
'min_samples_split': {
    'low': 2,
    'high': 5,
    'type': 'int'
    },
'min_samples_leaf':{
    'low': 1,
    'high': 5,
    'type': 'int'
    },
'max_features':{
    'values': ['auto', 'sqrt', 'log2'],
    'type': 'categorical'
    }
}

# %%
clf.DecisionTreeClassifier(True, params=params)
# Out:
# [I 2023-10-23 14:44:53,657] A new study created in memory with name: no-name-76719023-5ef2-4f3f-bbfe-11aa75080870
# [I 2023-10-23 14:44:55,486] Trial 0 finished with value: 0.6482692307692308 and parameters: {'max_depth': 12, 'criterion': 'gini', 'splitter': 'random', 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'log2'}. Best is trial 0 with value: 0.6482692307692308.
# [I 2023-10-23 14:44:57,331] Trial 1 finished with value: 0.6678846153846154 and parameters: {'max_depth': 10, 'criterion': 'entropy', 'splitter': 'random', 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.6678846153846154.
# [I 2023-10-23 14:44:59,149] Trial 2 finished with value: 0.6534615384615384 and parameters: {'max_depth': 14, 'criterion': 'entropy', 'splitter': 'best', 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 1 with value: 0.6678846153846154.
# [I 2023-10-23 14:45:00,978] Trial 3 finished with value: 0.5778846153846154 and parameters: {'max_depth': 15, 'criterion': 'gini', 'splitter': 'random', 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 'log2'}. Best is trial 1 with value: 0.6678846153846154.
# [I 2023-10-23 14:45:02,841] Trial 4 finished with value: 0.6690384615384617 and parameters: {'max_depth': 15, 'criterion': 'entropy', 'splitter': 'best', 'min_samples_split': 4, 'min_samples_leaf': 5, 'max_features': 'auto'}. Best is trial 4 with value: 0.6690384615384617.
# Number of finished trials:  5
# Best trial:
#   auc_roc_score:  0.6690384615384617
#   Params:
#     max_depth: 15
#     criterion: entropy
#     splitter: best
#     min_samples_split: 4
#     min_samples_leaf: 5
#     max_features: auto
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_27.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ### Random Forest

# %% [markdown]
# #### Set up parameters for tuning

# %%
params = {
'n_estimators': {
    'low': 80,
    'high': 120,
    'step': 10,
    'type': 'int'
    },
'criterion':{
    'values': ['gini', 'entropy'],
    'type': 'categorical'
    },
'min_samples_split': {
    'low': 2,
    'high': 5,
    'type': 'int'
    },
'min_samples_leaf':{
    'low': 1,
    'high': 5,
    'type': 'int'
    }
}

# %%
clf.RandomForestClassifier(is_tune=True,n_trials=5, params=params)
# Out:
# [I 2023-10-23 14:45:10,363] A new study created in memory with name: no-name-a4e982d3-9fe4-43ee-ab62-03d8638c4a2c
# [I 2023-10-23 14:45:12,362] Trial 0 finished with value: 0.7326923076923078 and parameters: {'n_estimators': 110, 'criterion': 'entropy', 'min_samples_split': 2, 'min_samples_leaf': 3}. Best is trial 0 with value: 0.7326923076923078.
# [I 2023-10-23 14:45:14,340] Trial 1 finished with value: 0.7126923076923077 and parameters: {'n_estimators': 120, 'criterion': 'entropy', 'min_samples_split': 3, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.7326923076923078.
# [I 2023-10-23 14:45:16,325] Trial 2 finished with value: 0.7226923076923077 and parameters: {'n_estimators': 80, 'criterion': 'gini', 'min_samples_split': 5, 'min_samples_leaf': 3}. Best is trial 0 with value: 0.7326923076923078.
# [I 2023-10-23 14:45:18,738] Trial 3 finished with value: 0.7326923076923078 and parameters: {'n_estimators': 110, 'criterion': 'gini', 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.7326923076923078.
# [I 2023-10-23 14:45:20,747] Trial 4 finished with value: 0.7075 and parameters: {'n_estimators': 80, 'criterion': 'entropy', 'min_samples_split': 2, 'min_samples_leaf': 5}. Best is trial 0 with value: 0.7326923076923078.
# Number of finished trials:  5
# Best trial:
#   auc_roc_score:  0.7326923076923078
#   Params:
#     n_estimators: 110
#     criterion: entropy
#     min_samples_split: 2
#     min_samples_leaf: 3
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_29.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ### Gradient Boosting Classification

# %% [markdown]
# #### Setup parameters for tuning

# %%
params = {
'n_estimators': 90,
'loss':'deviance',
'learning_rate':{
    'low': 0.6,
    'high':1.0,
    'type': 'float'
    },
'min_samples_split': {
    'low': 2,
    'high': 5,
    'type': 'int'
    },
'min_samples_leaf':{
    'low': 1,
    'high': 5,
    'type': 'int'
    },
'max_depth': {
    'low': 2,
    'high': 4,
    'type': 'int'
    }
}

# %%
clf.GradientBoostingClassifier(is_tune=True, n_trials=10, params=params)
# Out:
# [I 2023-10-24 02:13:10,363] A new study created in memory with name: no-name-eee99c32-129a-49db-ad70-d00af2c63a20
# [I 2023-10-24 02:13:12,331] Trial 0 finished with value: 0.7330769230769231 and parameters: {'n_estimators': 90, 'loss': 'deviance', 'learning_rate': 0.8, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_depth': 3}. Best is trial 0 with value: 0.7330769230769231.
# [I 2023-10-24 02:13:14,305] Trial 1 finished with value: 0.7326923076923078 and parameters: {'n_estimators': 90, 'loss': 'deviance', 'learning_rate': 0.6, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_depth': 4}. Best is trial 0 with value: 0.7330769230769231.
# [I 2023-10-24 02:13:16,301] Trial 2 finished with value: 0.7086538461538462 and parameters: {'n_estimators': 90, 'loss': 'deviance', 'learning_rate': 0.8, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_depth': 3}. Best is trial 0 with value: 0.7330769230769231.
# [I 2023-10-24 02:13:18,272] Trial 3 finished with value: 0.7478846153846155 and parameters: {'n_estimators': 90, 'loss': 'deviance', 'learning_rate': 1.0, 'min_samples_split': 3, 'min_samples_leaf': 5, 'max_depth': 4}. Best is trial 3 with value: 0.7478846153846155.
# [I 2023-10-24 02:13:20,344] Trial 4 finished with value: 0.6934615384615385 and parameters: {'n_estimators': 90, 'loss': 'deviance', 'learning_rate': 0.6, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_depth': 3}. Best is trial 3 with value: 0.7478846153846155.
# [I 2023-10-24 02:13:22,300] Trial 5 finished with value: 0.7082692307692309 and parameters: {'n_estimators': 90, 'loss': 'deviance', 'learning_rate': 0.6, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_depth': 2}. Best is trial 3 with value: 0.7478846153846155.
# [I 2023-10-24 02:13:24,269] Trial 6 finished with value: 0.713076923076923 and parameters: {'n_estimators': 90, 'loss': 'deviance', 'learning_rate': 0.7, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_depth': 4}. Best is trial 3 with value: 0.7478846153846155.
# [I 2023-10-24 02:13:26,152] Trial 7 finished with value: 0.7675000000000001 and parameters: {'n_estimators': 90, 'loss': 'deviance', 'learning_rate': 0.8, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_depth': 2}. Best is trial 7 with value: 0.7675000000000001.
# [I 2023-10-24 02:13:28,125] Trial 8 finished with value: 0.7578846153846155 and parameters: {'n_estimators': 90, 'loss': 'deviance', 'learning_rate': 0.7, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_depth': 3}. Best is trial 7 with value: 0.7675000000000001.
# [I 2023-10-24 02:13:30,167] Trial 9 finished with value: 0.7482692307692308 and parameters: {'n_estimators': 90, 'loss': 'deviance', 'learning_rate': 0.6, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_depth': 3}. Best is trial 7 with value: 0.7675000000000001.
# Number of finished trials:  10
# Best trial:
#   auc_roc_score:  0.7675000000000001
#   Params:
#     n_estimators: 90
#     loss: deviance
#     learning_rate: 0.8
#     min_samples_split: 3
#     min_samples_leaf: 2
#     max_depth: 2
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_31.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ### AdaBoostClassifier

# %% [markdown]
# #### Setup parameters for tuning

# %%
params={
    'n_estimators':{
        'low':30,
        'high':60,
        'step':10,
        'type':'int'
    },
    'learning_rate':{
        'low':0.7,
        'high':1.0,
        'type':'float',
    },
    'algorithm':{
        'values':['SAMME', 'SAMME.R'],
        'type': 'categorical'
    }
}

# %%
clf.AdaBoostClassifier(True,params=params,random_state = 42)
# Out:
# [I 2023-10-24 02:13:32,083] A new study created in memory with name: no-name-a934cb96-50d2-41b9-81a4-705e829aa1f1
# [I 2023-10-24 02:13:33,951] Trial 0 finished with value: 0.6938461538461539 and parameters: {'n_estimators': 40, 'learning_rate': 0.8999999999999999, 'algorithm': 'SAMME.R'}. Best is trial 0 with value: 0.6938461538461539.
# [I 2023-10-24 02:13:35,820] Trial 1 finished with value: 0.7282692307692308 and parameters: {'n_estimators': 60, 'learning_rate': 0.7999999999999999, 'algorithm': 'SAMME.R'}. Best is trial 1 with value: 0.7282692307692308.
# [I 2023-10-24 02:13:37,721] Trial 2 finished with value: 0.7082692307692309 and parameters: {'n_estimators': 30, 'learning_rate': 0.7, 'algorithm': 'SAMME'}. Best is trial 1 with value: 0.7282692307692308.
# [I 2023-10-24 02:13:39,613] Trial 3 finished with value: 0.7278846153846155 and parameters: {'n_estimators': 60, 'learning_rate': 1.0, 'algorithm': 'SAMME'}. Best is trial 1 with value: 0.7282692307692308.
# [I 2023-10-24 02:13:41,521] Trial 4 finished with value: 0.7282692307692308 and parameters: {'n_estimators': 60, 'learning_rate': 0.7999999999999999, 'algorithm': 'SAMME.R'}. Best is trial 1 with value: 0.7282692307692308.
# Number of finished trials:  5
# Best trial:
#   auc_roc_score:  0.7282692307692308
#   Params:
#     n_estimators: 60
#     learning_rate: 0.7999999999999999
#     algorithm: SAMME.R
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_33.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ### LightGBMClassifier

# %% [markdown]
# #### Setup parameters for tuning

# %%
params={
    'num_leaves':{
        'low':25,
        'high':35,
        'type':'int'
    },
    'learning_rate':{
        'low':0.1,
        'high':0.5,
        'type':'float'
    },
    'n_estimators':{
        'low':80,
        'high':120,
        'step':10,
        'type':'int'
    },
    'min_child_samples':{
        'low': 10,
        'high':20,
        'type': 'int'
    }
}

# %%
clf.LGBMClassifier(True, params=params)
# Out:
# [LightGBM] [Info] Number of positive: 218, number of negative: 396
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000122 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 664
# [LightGBM] [Info] Number of data points in the train set: 614, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.355049 -> initscore=-0.596919
# [LightGBM] [Info] Start training from score -0.596919
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [I 2023-10-24 02:14:42,480] A new study created in memory with name: no-name-7446f476-1fad-4e42-ae1b-1f47a746ccc4
# [LightGBM] [Info] Number of positive: 218, number of negative: 396
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000083 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 664
# [LightGBM] [Info] Number of data points in the train set: 614, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.355049 -> initscore=-0.596919
# [LightGBM] [Info] Start training from score -0.596919
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [I 2023-10-24 02:14:44,415] Trial 0 finished with value: 0.7378846153846155 and parameters: {'num_leaves': 30, 'learning_rate': 0.5, 'n_estimators': 100, 'min_child_samples': 19}. Best is trial 0 with value: 0.7378846153846155.
# [LightGBM] [Info] Number of positive: 218, number of negative: 396
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000061 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 664
# [LightGBM] [Info] Number of data points in the train set: 614, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.355049 -> initscore=-0.596919
# [LightGBM] [Info] Start training from score -0.596919
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [I 2023-10-24 02:14:46,366] Trial 1 finished with value: 0.713076923076923 and parameters: {'num_leaves': 26, 'learning_rate': 0.2, 'n_estimators': 90, 'min_child_samples': 19}. Best is trial 0 with value: 0.7378846153846155.
# [LightGBM] [Info] Number of positive: 218, number of negative: 396
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000059 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 664
# [LightGBM] [Info] Number of data points in the train set: 614, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.355049 -> initscore=-0.596919
# [LightGBM] [Info] Start training from score -0.596919
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [I 2023-10-24 02:14:48,283] Trial 2 finished with value: 0.7226923076923077 and parameters: {'num_leaves': 33, 'learning_rate': 0.5, 'n_estimators': 90, 'min_child_samples': 11}. Best is trial 0 with value: 0.7378846153846155.
# [LightGBM] [Info] Number of positive: 218, number of negative: 396
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000060 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 664
# [LightGBM] [Info] Number of data points in the train set: 614, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.355049 -> initscore=-0.596919
# [LightGBM] [Info] Start training from score -0.596919
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [I 2023-10-24 02:14:50,629] Trial 3 finished with value: 0.7378846153846155 and parameters: {'num_leaves': 30, 'learning_rate': 0.4, 'n_estimators': 120, 'min_child_samples': 12}. Best is trial 0 with value: 0.7378846153846155.
# [LightGBM] [Info] Number of positive: 218, number of negative: 396
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000061 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 664
# [LightGBM] [Info] Number of data points in the train set: 614, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.355049 -> initscore=-0.596919
# [LightGBM] [Info] Start training from score -0.596919
# [I 2023-10-24 02:14:52,567] Trial 4 finished with value: 0.7175 and parameters: {'num_leaves': 28, 'learning_rate': 0.1, 'n_estimators': 90, 'min_child_samples': 11}. Best is trial 0 with value: 0.7378846153846155.
# Number of finished trials:  5
# Best trial:
#   auc_roc_score:  0.7378846153846155
#   Params:
#     num_leaves: 30
#     learning_rate: 0.5
#     n_estimators: 100
#     min_child_samples: 19
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_35.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ### XGBClassifier

# %% [markdown]
# #### Setup parameters for tuning

# %%
params={
    'n_estimators':{
        'low': 10,
        'high': 40,
        'step':10,
        'type': 'int'
    },
    'max_depth':{
        'low':1,
        'high':5,
        'type':'int'
    },
    'learning_rate':{
        'low':0.2,
        'high':0.5,
        'type':'float'
    },
    'objective':{
        'values': ['binary:logistic'],
        'type':'categorical'
    }
}

# %%
clf.XGBClassifier(True, params=params)
# Out:
# [I 2023-10-24 02:15:06,731] A new study created in memory with name: no-name-d63c754a-715d-4ccc-8ebf-2844fb475084
# [I 2023-10-24 02:15:08,752] Trial 0 finished with value: 0.7575000000000001 and parameters: {'n_estimators': 10, 'max_depth': 4, 'learning_rate': 0.30000000000000004, 'objective': 'binary:logistic'}. Best is trial 0 with value: 0.7575000000000001.
# [I 2023-10-24 02:15:10,550] Trial 1 finished with value: 0.661923076923077 and parameters: {'n_estimators': 10, 'max_depth': 1, 'learning_rate': 0.2, 'objective': 'binary:logistic'}. Best is trial 0 with value: 0.7575000000000001.
# [I 2023-10-24 02:15:12,375] Trial 2 finished with value: 0.7823076923076924 and parameters: {'n_estimators': 20, 'max_depth': 4, 'learning_rate': 0.2, 'objective': 'binary:logistic'}. Best is trial 2 with value: 0.7823076923076924.
# [I 2023-10-24 02:15:14,171] Trial 3 finished with value: 0.7423076923076923 and parameters: {'n_estimators': 30, 'max_depth': 2, 'learning_rate': 0.2, 'objective': 'binary:logistic'}. Best is trial 2 with value: 0.7823076923076924.
# [I 2023-10-24 02:15:15,979] Trial 4 finished with value: 0.7726923076923078 and parameters: {'n_estimators': 10, 'max_depth': 5, 'learning_rate': 0.4, 'objective': 'binary:logistic'}. Best is trial 2 with value: 0.7823076923076924.
# Number of finished trials:  5
# Best trial:
#   auc_roc_score:  0.7823076923076924
#   Params:
#     n_estimators: 20
#     max_depth: 4
#     learning_rate: 0.2
#     objective: binary:logistic
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_37.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ## SupportVectorClassifier

# %% [markdown]
# #### Setup parameters for tuning

# %%
params={
    'C':{
        'low': 1e-5,
        'high':1e2,
        'type': 'loguniform'
    },
    'kernel':{
        'values': ['linear', 'rbf', 'poly'],
        'type':'categorical'
    },
    'degree':{
        'low':2,
        'high': 4,
        'type': 'int'
    }
}

# %%
clf.SupportVectorClassifier(True, params=params)
# Out:
# [I 2023-10-24 02:15:17,904] A new study created in memory with name: no-name-4f414029-6388-46ea-8a85-0ae8eb525e0b
# [I 2023-10-24 02:15:19,752] Trial 0 finished with value: 0.693076923076923 and parameters: {'C': 28.618023250470465, 'kernel': 'rbf', 'degree': 2}. Best is trial 0 with value: 0.693076923076923.
# [I 2023-10-24 02:15:21,542] Trial 1 finished with value: 0.5 and parameters: {'C': 3.707450464879586e-05, 'kernel': 'linear', 'degree': 2}. Best is trial 0 with value: 0.693076923076923.
# [I 2023-10-24 02:15:23,471] Trial 2 finished with value: 0.6351923076923077 and parameters: {'C': 0.06786159617050017, 'kernel': 'poly', 'degree': 3}. Best is trial 0 with value: 0.693076923076923.
# [I 2023-10-24 02:15:25,242] Trial 3 finished with value: 0.5 and parameters: {'C': 9.997058561414848e-05, 'kernel': 'rbf', 'degree': 3}. Best is trial 0 with value: 0.693076923076923.
# [I 2023-10-24 02:15:27,002] Trial 4 finished with value: 0.5 and parameters: {'C': 2.2614574993463535e-05, 'kernel': 'poly', 'degree': 4}. Best is trial 0 with value: 0.693076923076923.
# Number of finished trials:  5
# Best trial:
#   auc_roc_score:  0.693076923076923
#   Params:
#     C: 28.618023250470465
#     kernel: rbf
#     degree: 2
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_39.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ## Get runs

# %%
df_runs = clf.search_runs(exp_id)
print("Number of runs done : ", len(df_runs))
df_runs
# Out:
# Number of runs done :  53
#                                          artifact_uri  \
# 0   s3://models/2/43bd56169f414a6f85acce22780c763f...
# 1   s3://models/2/3545cadc2d464c83b639648e1d44a23d...
# 2   s3://models/2/71d42424ab624e43825f5b459b5107d8...
# 3   s3://models/2/c885099369a54fc8a451577c1df7d1a9...
# 4   s3://models/2/b0351e2247c141e681becbedb2884e48...
# 5   s3://models/2/e6c38cdb63c946688ae1fbfd4c92952b...
# 6   s3://models/2/c96280ad487c48a4934938bc8357180c...
# 7   s3://models/2/5f924648f44145a89aa32de6dc6a6358...
# 8   s3://models/2/1b124512011647599a5204b1fbbbdae9...
# 9   s3://models/2/5b78baa1edf34965aaca66a4da8439f2...
# 10  s3://models/2/d1301ebbc9454790a8a9a8def9c90d3c...
# 11  s3://models/2/6b444dbc533d4cbc9211397fa1d9425b...
# 12  s3://models/2/b7dfc7453c7a473f8a2c6da19959d41f...
# 13  s3://models/2/04dc653443364f378543c399b78ad99e...
# 14  s3://models/2/44edec4bea4748bb8d0d0a8c19008478...
# 15  s3://models/2/9412201a60e64210ba59f93a684b792a...
# 16  s3://models/2/cacd11b8330740fc8868fe5b6f21e281...
# 17  s3://models/2/815bfb9df8f04b16847a70519f585368...
# 18  s3://models/2/ca57156e15044e07b2ce3af35607b758...
# 19  s3://models/2/ba96cde19f3a4c4d9c690218bbe900ea...
# 20  s3://models/2/2d8950df523f429a956e5187b9b88ff8...
# 21  s3://models/2/158883185bb946208cdc3a13a68a56f8...
# 22  s3://models/2/0e0bb10fbfb84e4d9cd9f92654c5cc1a...
# 23  s3://models/2/fd2a2c1e0c5c4950bb5dd54c84c0c309...
# 24  s3://models/2/e22ef2fbf0b1418f83cad665b1d33f51...
# 25  s3://models/2/dd8c815906184987980c4a666980d411...
# 26  s3://models/2/9abf30dd99c74ea8a8a703a3c2275889...
# 27  s3://models/2/ea010e8f98c54796934cf8a937e24a00...
# 28  s3://models/2/36d3bab636204be8995566fbfbe53058...
# 29  s3://models/2/015796750ba04bb4881e20471a2abc01...
# 30  s3://models/2/5f116aa6dd844b8dabb7e6380e888d08...
# 31  s3://models/2/bc020123f02b4864af9ffa2c916c7e8e...
# 31          0.606061          8.746932                 0.612245
# 32          0.638298          7.625517                 0.681818
# 33          0.639175          7.849805                 0.659574
# 34          0.673684          6.952678                 0.711111
# 35          0.600000          8.074067                 0.675000
# 36          0.638298          7.625517                 0.681818
# 37          0.623656          7.849795                 0.674419
# 38          0.608696          8.074072                 0.666667
# 39          0.638298          7.625517                 0.681818
# 40          0.615385          7.849789                 0.682927
# 41          0.551020          9.868331                 0.562500
# 42          0.375000         11.213966                 0.500000
# 43          0.521739          9.868315                 0.571429
# 44          0.539326          9.195466                 0.615385
# 45          0.511111          9.868310                 0.575000
# 46          0.556701          9.644048                 0.574468
# 47          0.666667          6.952673                 0.720930
# 48          0.666667          6.952673                 0.720930
# 49          0.666667          6.952673                 0.720930
# 50          0.666667          6.952673                 0.720930
# 51          0.666667          6.952673                 0.720930
# 52          0.666667          6.952673                 0.720930
#
#     metrics.recall  metrics.roc_auc_score                params.C  ...  \
# 0             0.00               0.500000  2.2614574993463535e-05  ...
# 1             0.00               0.500000   9.997058561414848e-05  ...
# 2             0.28               0.635192     0.06786159617050017  ...
# 3             0.00               0.500000   3.707450464879586e-05  ...
# 4             0.54               0.693077      28.618023250470465  ...
# 5             0.58               0.737115                    None  ...
# 6             0.68               0.772692                    None  ...
# 7             0.60               0.742308                    None  ...
# 8             0.68               0.782308                    None  ...
# 9             0.42               0.661923                    None  ...
# 10            0.64               0.757500                    None  ...
# 11            0.66               0.748269                    None  ...
# 12            0.56               0.717500                    None  ...
# 13            0.62               0.737885                    None  ...
# 14            0.58               0.722692                    None  ...
# 15            0.58               0.713077                    None  ...
# 16            0.62               0.737885                    None  ...
# 17            0.62               0.737885                    None  ...
# 18            0.62               0.728269                    None  ...
# 19            0.60               0.727885                    None  ...
# 20            0.58               0.708269                    None  ...
# 21            0.62               0.728269                    None  ...
# 22            0.58               0.693846                    None  ...
# 23            0.64               0.723846                    None  ...
# 24            0.66               0.748269                    None  ...
# 25            0.66               0.757885                    None  ...
# 26            0.66               0.767500                    None  ...
# 27            0.58               0.713077                    None  ...
# 28            0.58               0.708269                    None  ...
# 29            0.56               0.693462                    None  ...
# 30            0.64               0.747885                    None  ...
# 31            0.60               0.708654                    None  ...
# 32            0.60               0.732692                    None  ...
# 33            0.62               0.733077                    None  ...
# 34            0.64               0.757500                    None  ...
# 35            0.54               0.707500                    None  ...
# 36            0.60               0.732692                    None  ...
# 37            0.58               0.722692                    None  ...
# 38            0.56               0.712692                    None  ...
# 39            0.60               0.732692                    None  ...
# 40            0.56               0.717500                    None  ...
# 41            0.54               0.669038                    None  ...
# 42            0.30               0.577885                    None  ...
# 43            0.48               0.653462                    None  ...
# 44            0.48               0.667885                    None  ...
# 45            0.46               0.648269                    None  ...
# 46            0.54               0.673846                    None  ...
# 47            0.62               0.752308                     0.7  ...
# 48            0.62               0.752308                     0.6  ...
# 49            0.62               0.752308                     0.6  ...
# 50            0.62               0.752308                     0.7  ...
# 45 2023-10-23 14:44:53.660000+00:00  FINISHED              -
# 46 2023-10-23 14:44:51.620000+00:00  FINISHED              -
# 47 2023-10-23 14:44:43.993000+00:00  FINISHED              -
# 48 2023-10-23 14:44:42.274000+00:00  FINISHED              -
# 49 2023-10-23 14:44:40.432000+00:00  FINISHED              -
# 50 2023-10-23 14:44:38.584000+00:00  FINISHED              -
# 51 2023-10-23 14:44:36.750000+00:00  FINISHED              -
# 52 2023-10-23 14:44:34.077000+00:00  FINISHED              -
#
#    tags.experiment_id  tags.experiment_name  \
# 0                   2  diabetes_prediction3
# 1                   2  diabetes_prediction3
# 2                   2  diabetes_prediction3
# 3                   2  diabetes_prediction3
# 4                   2  diabetes_prediction3
# 5                   2  diabetes_prediction3
# 6                   2  diabetes_prediction3
# 7                   2  diabetes_prediction3
# 8                   2  diabetes_prediction3
# 9                   2  diabetes_prediction3
# 10                  2  diabetes_prediction3
# 11                  2  diabetes_prediction3
# 12                  2  diabetes_prediction3
# 13                  2  diabetes_prediction3
# 14                  2  diabetes_prediction3
# 15                  2  diabetes_prediction3
# 16                  2  diabetes_prediction3
# 17                  2  diabetes_prediction3
# 18                  2  diabetes_prediction3
# 19                  2  diabetes_prediction3
# 20                  2  diabetes_prediction3
# 21                  2  diabetes_prediction3
# 22                  2  diabetes_prediction3
# 23                  2  diabetes_prediction3
# 24                  2  diabetes_prediction3
# 25                  2  diabetes_prediction3
# 26                  2  diabetes_prediction3
# 27                  2  diabetes_prediction3
# 28                  2  diabetes_prediction3
# 29                  2  diabetes_prediction3
# 30                  2  diabetes_prediction3
# 31                  2  diabetes_prediction3
# 32                  2  diabetes_prediction3
# 33                  2  diabetes_prediction3
# 34                  2  diabetes_prediction3
# 35                  2  diabetes_prediction3
# 36                  2  diabetes_prediction3
# 37                  2  diabetes_prediction3
# 38                  2  diabetes_prediction3
# 39                  2  diabetes_prediction3
# 40                  2  diabetes_prediction3
# 41                  2  diabetes_prediction3
# 42                  2  diabetes_prediction3
# 43                  2  diabetes_prediction3
# 44                  2  diabetes_prediction3
# 45                  2  diabetes_prediction3
# 46                  2  diabetes_prediction3
# 47                  2  diabetes_prediction3
# 48                  2  diabetes_prediction3
# 49                  2  diabetes_prediction3
# 50                  2  diabetes_prediction3
# 51                  2  diabetes_prediction3
# 52                  2  diabetes_prediction3
#
#                                         tags.features  \
# 0   ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 1   ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 2   ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 3   ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 4   ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 5   ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 6   ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 7   ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 8   ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 9   ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 10  ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 11  ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 12  ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 13  ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 14  ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 15  ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 16  ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 17  ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 18  ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 19  ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 20  ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 21  ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 22  ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 23  ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 24  ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 25  ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 26  ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 27  ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 28  ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 29  ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 30  ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 31  ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 32  ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 33  ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 34  ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 35  ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 36  ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 37  ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 38  ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 39  ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 40  ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 41  ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 42  ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 43  ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 44  ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 45  ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 46  ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 47  ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 48  ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 49  ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 50  ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 51  ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 52  ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
#
#                         tags.mlflow.log-model.history  \
# 0   [{"run_id": "43bd56169f414a6f85acce22780c763f"...
# 1   [{"run_id": "3545cadc2d464c83b639648e1d44a23d"...
# 2   [{"run_id": "71d42424ab624e43825f5b459b5107d8"...
# 3   [{"run_id": "c885099369a54fc8a451577c1df7d1a9"...
# 4   [{"run_id": "b0351e2247c141e681becbedb2884e48"...
# 5   [{"run_id": "e6c38cdb63c946688ae1fbfd4c92952b"...
# 6   [{"run_id": "c96280ad487c48a4934938bc8357180c"...
# 7   [{"run_id": "5f924648f44145a89aa32de6dc6a6358"...
# 8   [{"run_id": "1b124512011647599a5204b1fbbbdae9"...
# 9   [{"run_id": "5b78baa1edf34965aaca66a4da8439f2"...
# 10  [{"run_id": "d1301ebbc9454790a8a9a8def9c90d3c"...
# 11  [{"run_id": "6b444dbc533d4cbc9211397fa1d9425b"...
# 12  [{"run_id": "b7dfc7453c7a473f8a2c6da19959d41f"...
# 13  [{"run_id": "04dc653443364f378543c399b78ad99e"...
# 14  [{"run_id": "44edec4bea4748bb8d0d0a8c19008478"...
# 15  [{"run_id": "9412201a60e64210ba59f93a684b792a"...
# 16  [{"run_id": "cacd11b8330740fc8868fe5b6f21e281"...
# 17  [{"run_id": "815bfb9df8f04b16847a70519f585368"...
# 18  [{"run_id": "ca57156e15044e07b2ce3af35607b758"...
# 19  [{"run_id": "ba96cde19f3a4c4d9c690218bbe900ea"...
# 20  [{"run_id": "2d8950df523f429a956e5187b9b88ff8"...
# 21  [{"run_id": "158883185bb946208cdc3a13a68a56f8"...
# 22  [{"run_id": "0e0bb10fbfb84e4d9cd9f92654c5cc1a"...
# 23  [{"run_id": "fd2a2c1e0c5c4950bb5dd54c84c0c309"...
# 24  [{"run_id": "e22ef2fbf0b1418f83cad665b1d33f51"...
# 25  [{"run_id": "dd8c815906184987980c4a666980d411"...
# 26  [{"run_id": "9abf30dd99c74ea8a8a703a3c2275889"...
# 27  [{"run_id": "ea010e8f98c54796934cf8a937e24a00"...
# 28  [{"run_id": "36d3bab636204be8995566fbfbe53058"...
# 29  [{"run_id": "015796750ba04bb4881e20471a2abc01"...
# 30  [{"run_id": "5f116aa6dd844b8dabb7e6380e888d08"...
# 31  [{"run_id": "bc020123f02b4864af9ffa2c916c7e8e"...
# 32  [{"run_id": "1913e8374bcb47a08afcc7f8301883c0"...
# 33  [{"run_id": "69134bf957844ce3823b628c21beb45b"...
# 34  [{"run_id": "8c7dd4e7a609456795000814598234fa"...
# 35  [{"run_id": "d75cab73536d4552821c893dfae8bf9b"...
# 36  [{"run_id": "364a49c6553b47ca918ece8153c6210e"...
# 37  [{"run_id": "b1d0b3f232824090876949d69d04c649"...
# 38  [{"run_id": "69815e5aef4143759a175244716f25e6"...
# 39  [{"run_id": "0e64eedcc2b84220a12c80ef35604a52"...
# 40  [{"run_id": "6b86f607c8af40fb932b97389f504043"...
# 41  [{"run_id": "3f3b6339e823486ea96ae690b79b6874"...
# 42  [{"run_id": "f367c49fb7db415ba8aad67e8f8cbd3f"...
# 43  [{"run_id": "ad8002dc09d843529381df542b830d79"...
# 26  8c7dd4e7a609456795000814598234fa  9abf30dd99c74ea8a8a703a3c2275889
# 27  8c7dd4e7a609456795000814598234fa  ea010e8f98c54796934cf8a937e24a00
# 28  8c7dd4e7a609456795000814598234fa  36d3bab636204be8995566fbfbe53058
# 29  8c7dd4e7a609456795000814598234fa  015796750ba04bb4881e20471a2abc01
# 30  8c7dd4e7a609456795000814598234fa  5f116aa6dd844b8dabb7e6380e888d08
# 31  8c7dd4e7a609456795000814598234fa  bc020123f02b4864af9ffa2c916c7e8e
# 32  8c7dd4e7a609456795000814598234fa  1913e8374bcb47a08afcc7f8301883c0
# 33  8c7dd4e7a609456795000814598234fa  69134bf957844ce3823b628c21beb45b
# 34                              None  8c7dd4e7a609456795000814598234fa
# 35  6b86f607c8af40fb932b97389f504043  d75cab73536d4552821c893dfae8bf9b
# 36  6b86f607c8af40fb932b97389f504043  364a49c6553b47ca918ece8153c6210e
# 37  6b86f607c8af40fb932b97389f504043  b1d0b3f232824090876949d69d04c649
# 38  6b86f607c8af40fb932b97389f504043  69815e5aef4143759a175244716f25e6
# 39  6b86f607c8af40fb932b97389f504043  0e64eedcc2b84220a12c80ef35604a52
# 40                              None  6b86f607c8af40fb932b97389f504043
# 41  10174cb9ec084f57a76e2c0af0ebe338  3f3b6339e823486ea96ae690b79b6874
# 42  10174cb9ec084f57a76e2c0af0ebe338  f367c49fb7db415ba8aad67e8f8cbd3f
# 43  10174cb9ec084f57a76e2c0af0ebe338  ad8002dc09d843529381df542b830d79
# 44  10174cb9ec084f57a76e2c0af0ebe338  350a2c1e7df74f46a2ff57e2798eec58
# 45  10174cb9ec084f57a76e2c0af0ebe338  b631f784888c4fbda163bd09efba928b
# 46                              None  10174cb9ec084f57a76e2c0af0ebe338
# 47  d6aecb646d2941f084717752645dadd1  673b1a5231da4da4a57b66924e4a1cb5
# 48  d6aecb646d2941f084717752645dadd1  ad282d07758a4550b098e53bc448c80e
# 49  d6aecb646d2941f084717752645dadd1  09fdc8d1d68c4a71bb698b52fa16fe9a
# 50  d6aecb646d2941f084717752645dadd1  8ff001afe9f04aaf959c172f52635927
# 51  d6aecb646d2941f084717752645dadd1  14eeb79f4fb6458fa2e899f966f68908
# 52                              None  d6aecb646d2941f084717752645dadd1
#
#    tags.version.mlflow
# 0                2.0.1
# 1                2.0.1
# 2                2.0.1
# 3                2.0.1
# 4                2.0.1
# 5                2.0.1
# 6                2.0.1
# 7                2.0.1
# 8                2.0.1
# 9                2.0.1
# 10               2.0.1
# 11               2.0.1
# 12               2.0.1
# 13               2.0.1
# 14               2.0.1
# 15               2.0.1
# 16               2.0.1
# 17               2.0.1
# 18               2.0.1
# 19               2.0.1
# 20               2.0.1
# 21               2.0.1
# 22               2.0.1
# 23               2.0.1
# 24               2.0.1
# 25               2.0.1
# 26               2.0.1
# 27               2.0.1
# 28               2.0.1
# 29               2.0.1
# 30               2.0.1
# 31               2.0.1
# 32               2.0.1
# 33               2.0.1
# 34               2.0.1
# 35               2.0.1
# 36               2.0.1
# 37               2.0.1
# 38               2.0.1
# 39               2.0.1
# 40               2.0.1
# 41               2.0.1
# 42               2.0.1
# 43               2.0.1
# 44               2.0.1
# 45               2.0.1
# 46               2.0.1
# 47               2.0.1
# 48               2.0.1
# 49               2.0.1
# 50               2.0.1
# 51               2.0.1
# 52               2.0.1
#
# [53 rows x 38 columns]

# %%
top_runs = df_runs.sort_values(['metrics.roc_auc_score'],ascending=False)
top_runs.head()
# Out:
#                                          artifact_uri  \
# 8   s3://models/2/1b124512011647599a5204b1fbbbdae9...
# 6   s3://models/2/c96280ad487c48a4934938bc8357180c...
# 26  s3://models/2/9abf30dd99c74ea8a8a703a3c2275889...
# 25  s3://models/2/dd8c815906184987980c4a666980d411...
# 34  s3://models/2/8c7dd4e7a609456795000814598234fa...
#
#                            end_time experiment_id  metrics.accuracy_score  \
# 8  2023-10-24 02:15:12.356000+00:00             2                0.818182
# 6  2023-10-24 02:15:15.958000+00:00             2                0.805195
# 26 2023-10-24 02:13:26.136000+00:00             2                0.805195
# 25 2023-10-24 02:13:28.106000+00:00             2                0.792208
# 34 2023-10-24 02:13:30.201000+00:00             2                0.798701
#
#     metrics.f1_score  metrics.log_loss  metrics.precision_score  \
# 8           0.708333          6.279840                 0.739130
# 6           0.693878          6.728406                 0.708333
# 26          0.687500          6.728401                 0.717391
# 25          0.673469          7.176966                 0.687500
# 34          0.673684          6.952678                 0.711111
#
#     metrics.recall  metrics.roc_auc_score params.C  ...  \
# 8             0.68               0.782308     None  ...
# 6             0.68               0.772692     None  ...
# 26            0.66               0.767500     None  ...
# 25            0.66               0.757885     None  ...
# 34            0.64               0.757500     None  ...
#
#                          start_time    status tags.data_path  \
# 8  2023-10-24 02:15:10.552000+00:00  FINISHED              -
# 6  2023-10-24 02:15:14.174000+00:00  FINISHED              -
# 26 2023-10-24 02:13:24.271000+00:00  FINISHED              -
# 25 2023-10-24 02:13:26.154000+00:00  FINISHED              -
# 34 2023-10-24 02:13:08.460000+00:00  FINISHED              -
#
#    tags.experiment_id  tags.experiment_name  \
# 8                   2  diabetes_prediction3
# 6                   2  diabetes_prediction3
# 26                  2  diabetes_prediction3
# 25                  2  diabetes_prediction3
# 34                  2  diabetes_prediction3
#
#                                         tags.features  \
# 8   ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 6   ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 26  ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 25  ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
# 34  ['Pregnancies', 'Glucose', 'BloodPressure', 'S...
#
#                         tags.mlflow.log-model.history  \
# 8   [{"run_id": "1b124512011647599a5204b1fbbbdae9"...
# 6   [{"run_id": "c96280ad487c48a4934938bc8357180c"...
# 26  [{"run_id": "9abf30dd99c74ea8a8a703a3c2275889"...
# 25  [{"run_id": "dd8c815906184987980c4a666980d411"...
# 34  [{"run_id": "8c7dd4e7a609456795000814598234fa"...
#
#              tags.mlflow.parentRunId                       tags.run_id  \
# 8   6b444dbc533d4cbc9211397fa1d9425b  1b124512011647599a5204b1fbbbdae9
# 6   6b444dbc533d4cbc9211397fa1d9425b  c96280ad487c48a4934938bc8357180c
# 26  8c7dd4e7a609456795000814598234fa  9abf30dd99c74ea8a8a703a3c2275889
# 25  8c7dd4e7a609456795000814598234fa  dd8c815906184987980c4a666980d411
# 34                              None  8c7dd4e7a609456795000814598234fa
#
#    tags.version.mlflow
# 8                2.0.1
# 6                2.0.1
# 26               2.0.1
# 25               2.0.1
# 34               2.0.1
#
# [5 rows x 38 columns]

# %% [markdown]
# ## Selecting Best Model

# %%
artifacts = top_runs.iloc[0]["artifact_uri"]
run_id = top_runs.iloc[0]["run_id"]
model_name = top_runs.iloc[0]["run_name"] 


print('Best model_artifacts :',artifacts)
print("=" * 100)
print('Best model run_id :',run_id)
print("=" * 100)
print('Best model :',model_name)
print("=" * 100)
print("Best model experiment id :",exp_id)
# Out:
# Best model_artifacts : s3://models/2/1b124512011647599a5204b1fbbbdae9/artifacts
# ====================================================================================================
# Best model run_id : 1b124512011647599a5204b1fbbbdae9
# ====================================================================================================
# Best model : diabetes_prediction3_2_xgb_classifier_tuned
# ====================================================================================================
# Best model experiment id : 2

# %% [markdown]
# ## Registering Best Model

# %%
result = clf.register_model(
    run_id=run_id,
    model_name=model_name
)
# Out:
# 2023/10/24 02:18:10 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation.                     Model name: diabetes_prediction3_2_xgb_classifier_tuned, version 1

# %%
result = clf.change_stage(
    # run_id=run_id,
    model_name=model_name,
    ver_list=[1],
    stage="Production"
)

# %% [markdown]
# ## Fetching Model

# %%
location = f"{artifacts}/{model_name}"

# %%
model = load_model(location)

# %% [markdown]
# ## Predict

# %%
y_pred = model.predict(X_test)

# %%
# Prepare variable as DataFrame in pandas
df = pd.DataFrame(X_test)

# Add the target variable to df
df["y_pred"] = y_pred

# %%
df
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0       0.364502  0.893340       0.523491      -1.264861 -0.692680  0.275321
# 1      -1.177622  0.168269       0.105783      -0.016216 -0.692680 -0.587738
# 2      -1.177622 -1.092724       0.732345       0.670539  0.449328  0.891792
# 3       0.056077 -1.344923      -0.311925      -1.264861 -0.692680  0.316419
# 4      -0.560772  2.469581       0.105783       1.544590  4.268204 -0.163058
# ..           ...       ...            ...            ...       ...       ...
# 149    -0.560772 -0.210029       0.001356       0.108648  0.166110  0.330119
# 150    -0.252347 -0.966625      -0.520779      -0.578106 -0.199332 -0.943921
# 151     1.289776 -0.367653       0.627918      -1.264861 -0.692680 -0.971320
# 152     0.056077 -0.872050       0.105783       0.732971  0.111294  0.193125
# 153     0.672927  1.114014       0.523491       1.294861  0.586369  1.974041
#
#      DiabetesPedigreeFunction       Age  y_pred
# 0                   -0.769665  2.703247       1
# 1                   -0.660715  0.263332       0
# 2                   -0.724269 -0.830424       0
# 3                   -0.246100 -0.662154       0
# 4                   -0.951249  1.693627       1
# ..                        ...       ...     ...
# 149                 -0.476106 -0.578019       0
# 150                 -0.621372 -0.914559       0
# 151                  1.161170  0.095062       0
# 152                 -0.079649 -0.914559       0
# 153                  0.298649 -0.493883       1
#
# [154 rows x 9 columns]
